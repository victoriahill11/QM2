# %% [markdown]
# <a href="https://colab.research.google.com/github/victoriahill11/QM2/blob/main/Corrution_index_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pylab
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pylab
from datetime import datetime

# %%
from google.colab import files
uploaded = files.upload ()
# Out:
#      <input type="file" id="files-3c16b4f4-3f99-427e-ae28-ab7e44834129" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c16b4f4-3f99-427e-ae28-ab7e44834129">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('CPI-2003_200602_113929.csv')
df.head()
# Out:
#      country  iso region  score  rank   interval
# 0    Albania  ALB    ECA    2.5    92  1.9 - 3.2
# 1    Algeria  DZA   MENA    2.6    88  2.0 - 3.0
# 2     Angola  AGO    SSA    1.8   124  1.4 - 2.0
# 3  Argentina  ARG    AME    2.5    92  1.6 - 3.2
# 4    Armenia  ARM    ECA    3.0    78  2.2 - 4.1

# %%
# Assuming your dataframe is named 'df'
df_mena = df[df['region'] == 'MENA']

print(df_mena)
# Out:
#                   country  iso region  score  rank   interval
# 1                 Algeria  DZA   MENA    2.6    88  2.0 - 3.0
# 8                 Bahrain  BHR   MENA    6.1    27  5.5 - 7.4
# 33                  Egypt  EGY   MENA    3.3    70  1.8 - 5.3
# 52                   Iran  IRN   MENA    3.0    78  1.5 - 3.6
# 53                   Iraq  IRQ   MENA    2.2   113  1.2 - 3.4
# 55                 Israel  ISR   MENA    7.0    21  4.7 - 8.1
# 59                 Jordan  JOR   MENA    4.6    43  3.6 - 6.5
# 62                 Kuwait  KWT   MENA    5.3    35  3.3 - 7.4
# 65                Lebanon  LBN   MENA    3.0    78  2.1 - 3.6
# 66                  Libya  LBY   MENA    2.1   118  1.7 - 2.7
# 77                Morocco  MAR   MENA    3.3    70  2.4 - 5.5
# 86                   Oman  OMN   MENA    6.3    26  5.5 - 7.3
# 88              Palestine  PSE   MENA    3.0    78  2.0 - 4.3
# 96                  Qatar  QAT   MENA    5.6    32  5.5 - 5.7
# ...

# %%
print(df_mena.to_string(index=False))
# Out:
#              country iso region  score  rank  interval
#              Algeria DZA   MENA    2.6    88 2.0 - 3.0
#              Bahrain BHR   MENA    6.1    27 5.5 - 7.4
#                Egypt EGY   MENA    3.3    70 1.8 - 5.3
#                 Iran IRN   MENA    3.0    78 1.5 - 3.6
#                 Iraq IRQ   MENA    2.2   113 1.2 - 3.4
#               Israel ISR   MENA    7.0    21 4.7 - 8.1
#               Jordan JOR   MENA    4.6    43 3.6 - 6.5
#               Kuwait KWT   MENA    5.3    35 3.3 - 7.4
#              Lebanon LBN   MENA    3.0    78 2.1 - 3.6
#                Libya LBY   MENA    2.1   118 1.7 - 2.7
#              Morocco MAR   MENA    3.3    70 2.4 - 5.5
#                 Oman OMN   MENA    6.3    26 5.5 - 7.3
#            Palestine PSE   MENA    3.0    78 2.0 - 4.3
#                Qatar QAT   MENA    5.6    32 5.5 - 5.7
#         Saudi Arabia SAU   MENA    4.5    46 2.8 - 7.4
#                Syria SYR   MENA    3.4    66 2.0 - 5.0
# ...
